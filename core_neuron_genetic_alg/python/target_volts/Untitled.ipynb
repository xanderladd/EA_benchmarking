# %%
import h5py
import matplotlib.pyplot as plt

# %%
t1 = h5py.File("allen_data_target_volts_10000.hdf5", 'r')
t2 = h5py.File('target_volts_485835016.hdf5', 'r')

for idx, key in enumerate(t2.keys()):
    plt.figure()
    plt.plot(t2[key][:])
    plt.title("stim " + str(key) + " @ " + str(idx))
